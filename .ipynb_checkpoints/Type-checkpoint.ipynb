# %%
type(8)
# Out:
# int

# %%
type('dog')
# Out:
# str

# %%
type(4.1)
# Out:
# float

# %%
x=7

# %%
type(x)
# Out:
# int

# %%
x=9.6

# %%
type(x)
# Out:
# float

# %%
x='car'

# %%
type(x)
# Out:
# str
