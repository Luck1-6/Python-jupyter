# %%
f'{17.489:.2f}'
# Out:
# '17.49'

# %%
f'{10:d}'
# Out:
# '10'

# %%
f'{65:c} {97:c}'
# Out:
# 'A a'

# %%
f'{"hello":s} {7}'
# Out:
# 'hello 7'

# %%
f'[{27:10d}]'
# Out:
# '[        27]'

# %%
f'[{3.5:10f}]'
# Out:
# '[  3.500000]'

# %%
f'[{"hello":10}]'
# Out:
# '[hello     ]'

# %%
f'[{3.5:<10f}]'
# Out:
# '[3.500000  ]'

# %%
f'[{25:<10d}]'
# Out:
# '[25        ]'

# %%
f'[{"hello":>15}]'
# Out:
# '[          hello]'

# %%
f'[{38:^10d}]'
# Out:
# '[    38    ]'

# %%
f'[{4.8:^8f}]'
# Out:
# '[4.800000]'

# %%
print(f'[{"Amanda":>10}]\n[{"Amanda":^10}]\n[{"Amanda":<10}]')
# Out:
# [    Amanda]
# [  Amanda  ]
# [Amanda    ]

# %%
f'[{27:+10d}]'
# Out:
# '[       +27]'

# %%
print(f'{10240.473:+10,.2f}\n{-3210.9521:+10,.2f}')
# Out:
# +10,240.47
#  -3,210.95

# %%
'{:.2f}'.format(17.886)
# Out:
# '17.89'

# %%
'{} {}'.format('Amanda', 'Cyan')
# Out:
# 'Amanda Cyan'

# %%
'{0} {0} {1}'.format('Happy', 'Birthday')
# Out:
# 'Happy Happy Birthday'

# %%
'{first} {last}'.format(first='Amanda', last='Cyan')
# Out:
# 'Amanda Cyan'

# %%
print('{:c}{:c}{:c}'.format(58,45,41))
# Out:
# :-)

# %%
print('[{0:<10}]\n[{0:^10}]\n[{0:>10}]'.format('Amanda'))
# Out:
# [Amanda    ]
# [  Amanda  ]
# [    Amanda]

# %%
print('{:+10,.2f}\n{:+10,.2f}'.format(10240.473,-3561.6780))
# Out:
# +10,240.47
#  -3,561.68
