# %%
def average(*args):
    return sum(args)/len(args)

# %%
average(1, 10)
# Out:
# 5.5

# %%
def calculate_product(*args):
    product=1
    for value in args:
        product*=value
    return product

# %%
calculate_product(3, 5, 8)
# Out:
# 120

# %%
s ='Hello'

# %%
s.lower()
# Out:
# 'hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
from math import ceil, floor

# %%
ceil(10.3)
# Out:
# 11

# %%
floor(10.7)
# Out:
# 10

# %%
e='hello'

# %%
from math import *

# %%
e
# Out:
# 2.718281828459045

# %%
x=7

# %%
id(x)
# Out:
# 140710684011128

# %%
def cube(number):
    print('id (number):' , id(number))
    return number**3
cube(7)
# Out:
# id (number): 140710684011128
# 343

# %%
def cube(number):
    print('number is x:', number is x)
    return number**3

# %%
cube(x)
# Out:
# number is x: True
# 343

# %%
def square(number):
    """calculate the square of number"""
    return number**2

# %%
square(7)
# Out:
# 49

# %%
def square(number):
    """calculate the square of number"""
    return number**0.5

# %%
square(5)
