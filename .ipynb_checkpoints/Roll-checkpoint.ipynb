# %%
import random

# %%
for roll in range(10):
    print(random.randrange(1,7), end=' ')
# Out:
# 5 2 2 6 3 1 6 1 2 6

# %%
random.seed(5)

# %%
for roll in range(10):
    print(random.randrange(1,7), end=' ')
# Out:
# 5 3 6 3 6 6 6 5 1 4

# %%
random.seed(5)

# %%
for roll in range(10):
    print(random.randrange(1,7), end=' ')
# Out:
# 5 3 6 3 6 6 6 5 1 4
