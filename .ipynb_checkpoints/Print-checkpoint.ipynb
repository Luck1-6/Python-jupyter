# %%
print("Welcome to python")
# Out:
# Welcome to python

# %%
print("Welcome","to","python")
# Out:
# Welcome to python

# %%
print("welcome\nto\npython")
# Out:
# welcome
# to
# python

# %%
print('welcome\tto\tpython')
# Out:
# welcome	to	python

# %%
print('Display \"hi\" in quotes')

# %%
print("""Display "hii" and 'bye' in quotes""")

# %%
triple_quoted_strings="""This is a triple quoted 
string that spans two lines"""

# %%
print(triple_quoted_strings)

# %%
triple_quoted_strings

# %%
print('this is a longer string, so we \
split it over two lines')
# Out:
# this is a longer string, so we split it over two lines

# %%
print('sum is', 3 + 7)
# Out:
# sum is 10

# %%
print("""This is a lenghty 
   multiline string containing
 a few lines\
 of text""")
# Out:
# This is a lenghty
#    multiline string containing
#  a few lines of text

# %%
string="""This is a lenghty 
   multiline string containing
 a few lines\
 of text"""

# %%
string
# Out:
# 'This is a lenghty \n   multiline string containing\n a few lines of text'

# %%
print('love'is'life')
# Out:
# False
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# C:\Users\hp\AppData\Local\Temp\ipykernel_10596\4169444821.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   print('love'is'life')

# %%
print('love\'is\'life')
# Out:
# love'is'life

# %%
print('love"is"life')
# Out:
# love"is"life

# %%
print("""Always"love" and "care" yourself""")
# Out:
# Always"love" and "care" yourself

# %%
print('welcome\tto\tpython')
# Out:
# welcome	to	python
