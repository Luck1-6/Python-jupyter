# %%
gender='female'

# %%
age=70

# %%
if gender=='female'and age>=65:
    print('senior female')
# Out:
# senior female

# %%
semester_average=83

# %%
final_exam=95

# %%
if semester_average>=85 or final_exam>=90:
    print('student gets on A')
# Out:
# student gets on A

# %%
grade=87

# %%
if not grade==-1:
    print('next grade is',grade)
# Out:
# next grade is 87

# %%
i=1

# %%
j=2

# %%
k=3

# %%
m=3

# %%
(i>=4) and (j<4)
# Out:
# False

# %%
(m<=99) and(k<m)
# Out:
# False

# %%
(k+m<j) or (3-j>=k)
# Out:
# False

# %%
not (k<m)
# Out:
# True
