# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
head=Node(10)
head.next=Node(20)
head.next.next=Node(30)
head.next.next.next=Node(40)

# %%
def traverse(head):
    p=head
    while p!=None:
        print(p.data)
        p=p.next
traverse(head)
# Out:
# 10
# 20
# 30
# 40

# %%
def counthead(head):
    p=head
    count=0
    while p!=None:
        count+=1
        p=p.next
    return count    
    print (count)    
counthead(head)
# Out:
# 4

# %%
def insertbegin(head):
    p=Node(50)
    p.next=head
    head=p
    while p!=None:
        print(p.data)
        p=p.next
insertbegin(head)
# Out:
# 50
# 10
# 20
# 30
# 40

# %%
def sum_data(head):
    p=head
    sum=0
    while p!=None:
        sum=sum+(p.data)
        p=p.next
    return sum
    print(sum)
sum_data(head)
# Out:
# 100

# %%
def max_data(head):
    p=head
    max=0
    while p!=None:
        if (p.data)>max:
            max=p.data
            p=p.next
    return max
    print(max)
max_data(head)
# Out:
# 40

# %%
def search(head):
    p=head
    key=20
    while p!=None:
        if (key)==(p.data):
            return 1
            p=p.next 
    return 0 
    print('yes')
search(head)
