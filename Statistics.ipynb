# %%
grades=[85, 93, 45, 45, 89, 85]

# %%
sum(grades)/len(grades)
# Out:
# 73.66666666666667

# %%
import statistics

# %%
statistics.mean(grades)
# Out:
# 73.66666666666667

# %%
statistics.median(grades)
# Out:
# 85.0

# %%
statistics.mode(grades)
# Out:
# 85

# %%
sorted(grades)
# Out:
# [45, 45, 85, 85, 89, 93]
