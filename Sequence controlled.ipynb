# %%
total=0
grade_counter=0
grades=[32,56,60,23,80]

# %%
for grade in grades:
    total+=grade
    grade_counter+=1

# %%
average=total/grade_counter
print(f'class averge is {average}')
# Out:
# class averge is 50.2
